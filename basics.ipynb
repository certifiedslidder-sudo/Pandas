# %%
#Install pandas

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import pandas
import pandas as pd

# %%
pd.__version__
# Out:
# '3.0.0'

# %% [markdown]
# # Dataframe

# %%
 # 1. Create dataframe
df = pd.DataFrame([11,22,33], columns=['col_Name'])
print(df) # by default start by 0
# Out:
#    col_Name
# 0        11
# 1        22
# 2        33

# %%
print(type(df))
# Out:
# <class 'pandas.DataFrame'>

# %%
data = {
    
    'Name': ['madhav','vishakha','lalita','rishabh'],
    'Age' : [16,17,18,19],
    'Salary' : [6000,8000,9000,10000]
}

# %%
df = pd.DataFrame(data)
print(df)
print(type(df))
# Out:
#        Name  Age  Salary
# 0    madhav   16    6000
# 1  vishakha   17    8000
# 2    lalita   18    9000
# 3   rishabh   19   10000
# <class 'pandas.DataFrame'>

# %% [markdown]
# ## More understanding on Dataframe

# %%
df.head() # print top rows
# Out:
#        Name  Age  Salary
# 0    madhav   16    6000
# 1  vishakha   17    8000
# 2    lalita   18    9000
# 3   rishabh   19   10000

# %%
df.head(2) # print 2 top rows
# Out:
#        Name  Age  Salary
# 0    madhav   16    6000
# 1  vishakha   17    8000

# %%
df.tail()  # print bottom rows
# Out:
#        Name  Age  Salary
# 0    madhav   16    6000
# 1  vishakha   17    8000
# 2    lalita   18    9000
# 3   rishabh   19   10000

# %%
df.tail(3) # print bottom 3 rows
# Out:
#        Name  Age  Salary
# 1  vishakha   17    8000
# 2    lalita   18    9000
# 3   rishabh   19   10000

# %%
df.shape
# Out:
# (4, 3)

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Salary'], dtype='str')

# %%
df.rename(columns={'Salary' :'Monthly_salary'}, inplace = True)  #changed in same dataframe

# or use df1 = df.rename(columns={'Salary' : 'Monthly_salary'})

# %%
df
# Out:
#        Name  Age  Monthly_salary
# 0    madhav   16            6000
# 1  vishakha   17            8000
# 2    lalita   18            9000
# 3   rishabh   19           10000

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            4 non-null      str
#  1   Age             4 non-null      int64
#  2   Monthly_salary  4 non-null      int64
# dtypes: int64(2), str(1)
# memory usage: 228.0 bytes

# %%
df.describe() # give statisistic summary about numerical type columns
# Out:
#              Age  Monthly_salary
# count   4.000000        4.000000
# mean   17.500000     8250.000000
# std     1.290994     1707.825128
# min    16.000000     6000.000000
# 25%    16.750000     7500.000000
# 50%    17.500000     8500.000000
# 75%    18.250000     9250.000000
# max    19.000000    10000.000000

# %% [markdown]
# ## SAVE AND LOAD DATA FROM CSV

# %%
df.to_csv('Test_data.csv', index = False)   # here df = name of dataframe 
# export dataframe

# %%
load_df = pd.read_csv('Test_data.csv') # function to load dataframe
#import dataframe
load_df                 # i incremented rishab's salary in excel
# Out:
#        Name  Age  Monthly_salary
# 0    madhav   16            6000
# 1  vishakha   17            8000
# 2    lalita   18            9000
# 3   rishabh   19           12000
